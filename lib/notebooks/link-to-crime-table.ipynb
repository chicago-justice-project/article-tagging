# %%
import tag_article
from tag_article import LemmaTokenizer
import load_data as ld

import sklearn.metrics

import numpy as np

# %%
crimes, crime_strings = ld.load_crime_data()

# %%
articles = ld.load_data()
# Out:
# C:\Users\kevin.rose\AppData\Local\Continuum\Anaconda2\envs\py35\lib\site-packages\IPython\core\interactiveshell.py:2881: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
clf, vectorizer = tag_article.load_model()

# %%
v_c = vectorizer.transform(crime_strings.fillna('').values)

# %%
v_a = vectorizer.transform([articles['bodytext'].values[32]])

# %%
cs = sklearn.metrics.pairwise.cosine_similarity(v_c, v_a).flatten()

# %%
sorted_idx = np.argsort(cs, 0)

# %%
cs[sorted_idx[-1]]
# Out:
# 0.16633695978261512

# %%
print(articles['bodytext'].values[32])
crimes.iloc[sorted_idx[-10:], :]
# Out:
# #  Cops: Man shot to death after leaving wake of gang member
#
# SUN-TIMES MEDIA WIRE  May 24, 2011  02:14PM
#
#   *   *   *   * [ Reprints ][1]
#   * [ E-Mail ][2]
#   * [ Print ][3]
#
# A 23-year-old man was shot to death early Tuesday in the Logan Square
# neighborhood shortly after attending the wake of a gang member, according to
# police.
#
# The victim and another man had left the wake when someone opened fire,
# striking the victim twice, police News Affairs Officer Michael Sullivan said.
#
# Police were notified at 4:17 a.m. and the body was found in an alley on the
# 2700 block of North Albany Avenue, according to Sullivan.
#
# The shooting is believed to be gang-related, Sullivan said. The victim was not
# believed to be in a gang but the man he was with is in a gang, Sullivan said.
#
# The shooter was described as a Hispanic male, 5-foot-8 to 5-foot-9, and
# 150-160 pounds.
#
# No one was in custody as of Tuesday afternoon.
#
# ...
